# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import os

# %%
folder = './Dataset/'
for folders in os.scandir(folder):
    if folders.is_dir():
        count = 1
        for files in os.listdir(folders):
            source = folder + str(folders) + files
            dstn = folder + str(folders) + str(count) + '.png'
#             print(source)
#             print(dstn)
            os.rename(source, dstn)
            count += 1
# Out:
# ./Dataset/<DirEntry 'with_mask'>63.jpg
# ./Dataset/<DirEntry 'with_mask'>1.png
# ./Dataset/<DirEntry 'with_mask'>1_0_2 copy 6.jpg
# ./Dataset/<DirEntry 'with_mask'>2.png
# ./Dataset/<DirEntry 'with_mask'>0_0_24 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>3.png
# ./Dataset/<DirEntry 'with_mask'>with_mask439.jpg
# ./Dataset/<DirEntry 'with_mask'>4.png
# ./Dataset/<DirEntry 'with_mask'>189.jpg
# ./Dataset/<DirEntry 'with_mask'>5.png
# ./Dataset/<DirEntry 'with_mask'>0_0_8 copy 10.jpg
# ./Dataset/<DirEntry 'with_mask'>6.png
# ./Dataset/<DirEntry 'with_mask'>0_0_25 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>7.png
# ./Dataset/<DirEntry 'with_mask'>77.jpg
# ./Dataset/<DirEntry 'with_mask'>8.png
# ./Dataset/<DirEntry 'with_mask'>with_mask405.jpg
# ./Dataset/<DirEntry 'with_mask'>9.png
# ./Dataset/<DirEntry 'with_mask'>with_mask363.jpg
# ./Dataset/<DirEntry 'with_mask'>10.png
# ./Dataset/<DirEntry 'with_mask'>with_mask377.jpg
# ./Dataset/<DirEntry 'with_mask'>11.png
# ./Dataset/<DirEntry 'with_mask'>with_mask411.jpg
# ./Dataset/<DirEntry 'with_mask'>12.png
# ./Dataset/<DirEntry 'with_mask'>with_mask388.jpg
# ./Dataset/<DirEntry 'with_mask'>13.png
# ./Dataset/<DirEntry 'with_mask'>0_0_34.jpg
# ./Dataset/<DirEntry 'with_mask'>14.png
# ./Dataset/<DirEntry 'with_mask'>1_0_20.jpg
# ./Dataset/<DirEntry 'with_mask'>15.png
# ./Dataset/<DirEntry 'with_mask'>162.jpg
# ./Dataset/<DirEntry 'with_mask'>16.png
# ./Dataset/<DirEntry 'with_mask'>176.jpg
# ./Dataset/<DirEntry 'with_mask'>17.png
# ./Dataset/<DirEntry 'with_mask'>0_0_7 copy 7.jpg
# ./Dataset/<DirEntry 'with_mask'>18.png
# ./Dataset/<DirEntry 'with_mask'>with_mask161.png
# ./Dataset/<DirEntry 'with_mask'>19.png
# ./Dataset/<DirEntry 'with_mask'>0_0_20.jpg
# ./Dataset/<DirEntry 'with_mask'>20.png
# ./Dataset/<DirEntry 'with_mask'>88.jpg
# ./Dataset/<DirEntry 'with_mask'>21.png
# ./Dataset/<DirEntry 'with_mask'>1_0_8.jpg
# ./Dataset/<DirEntry 'with_mask'>22.png
# ./Dataset/<DirEntry 'with_mask'>0_0_6 copy 23.jpg
# ./Dataset/<DirEntry 'with_mask'>23.png
# ./Dataset/<DirEntry 'with_mask'>with_mask149.jpg
# ./Dataset/<DirEntry 'with_mask'>24.png
# ./Dataset/<DirEntry 'with_mask'>0_0_4 copy 9.jpg
# ./Dataset/<DirEntry 'with_mask'>25.png
# ./Dataset/<DirEntry 'with_mask'>with_mask175.jpg
# ./Dataset/<DirEntry 'with_mask'>26.png
# ./Dataset/<DirEntry 'with_mask'>0_1_18 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>27.png
# ./Dataset/<DirEntry 'with_mask'>0_0_006GRRUely1gayhi8krcyj31jk2247wh.jpg
# ./Dataset/<DirEntry 'with_mask'>28.png
# ./Dataset/<DirEntry 'with_mask'>348.jpg
# ./Dataset/<DirEntry 'with_mask'>29.png
# ./Dataset/<DirEntry 'with_mask'>1_0_1 copy 8.jpg
# ./Dataset/<DirEntry 'with_mask'>30.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 13.jpg
# ./Dataset/<DirEntry 'with_mask'>31.png
# ./Dataset/<DirEntry 'with_mask'>0_0_18 copy 8.jpg
# ./Dataset/<DirEntry 'with_mask'>32.png
# ./Dataset/<DirEntry 'with_mask'>with_mask029.jpg
# ./Dataset/<DirEntry 'with_mask'>33.png
# ./Dataset/<DirEntry 'with_mask'>0_0_80730d69ly1gbpcepdazoj20ku0ubmzr.jpg
# ./Dataset/<DirEntry 'with_mask'>34.png
# ./Dataset/<DirEntry 'with_mask'>0_0_4 copy 16.jpg
# ./Dataset/<DirEntry 'with_mask'>35.png
# ./Dataset/<DirEntry 'with_mask'>with_mask015.jpg
# ./Dataset/<DirEntry 'with_mask'>36.png
# ./Dataset/<DirEntry 'with_mask'>with_mask001.jpg
# ./Dataset/<DirEntry 'with_mask'>37.png
# ./Dataset/<DirEntry 'with_mask'>228.jpg
# ./Dataset/<DirEntry 'with_mask'>38.png
# ./Dataset/<DirEntry 'with_mask'>0_0_29 copy 3.jpg
# ./Dataset/<DirEntry 'with_mask'>39.png
# ./Dataset/<DirEntry 'with_mask'>214.jpg
# ./Dataset/<DirEntry 'with_mask'>40.png
# ./Dataset/<DirEntry 'with_mask'>0_0_8bf8364ed98ac9cbeb3c45e87270b886.jpeg
# ./Dataset/<DirEntry 'with_mask'>41.png
# ./Dataset/<DirEntry 'with_mask'>0_0_3 copy 32.jpg
# ./Dataset/<DirEntry 'with_mask'>42.png
# ./Dataset/<DirEntry 'with_mask'>0_0_57490f54gy1fga7jkq5tyj21kw215dsz.jpg
# ./Dataset/<DirEntry 'with_mask'>43.png
# ./Dataset/<DirEntry 'with_mask'>0_0_3 copy 26.jpg
# ./Dataset/<DirEntry 'with_mask'>44.png
# ./Dataset/<DirEntry 'with_mask'>0_1_48.jpg
# ./Dataset/<DirEntry 'with_mask'>45.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 4 2.jpg
# ./Dataset/<DirEntry 'with_mask'>46.png
# ./Dataset/<DirEntry 'with_mask'>200.jpg
# ./Dataset/<DirEntry 'with_mask'>47.png
# ./Dataset/<DirEntry 'with_mask'>0_0_21 copy 5.jpg
# ./Dataset/<DirEntry 'with_mask'>48.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 82.jpg
# ./Dataset/<DirEntry 'with_mask'>49.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 96.jpg
# ./Dataset/<DirEntry 'with_mask'>50.png
# ./Dataset/<DirEntry 'with_mask'>with_mask203.jpg
# ./Dataset/<DirEntry 'with_mask'>51.png
# ./Dataset/<DirEntry 'with_mask'>0_0_e87cac09ly1g946kdzavqj20da09o3z9.jpg
# ./Dataset/<DirEntry 'with_mask'>52.png
# ./Dataset/<DirEntry 'with_mask'>0_0_16 copy 5.jpg
# ./Dataset/<DirEntry 'with_mask'>53.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 41.jpg
# ./Dataset/<DirEntry 'with_mask'>54.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 55.jpg
# ./Dataset/<DirEntry 'with_mask'>55.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 69.jpg
# ./Dataset/<DirEntry 'with_mask'>56.png
# ./Dataset/<DirEntry 'with_mask'>0_0_10 copy 10.jpg
# ./Dataset/<DirEntry 'with_mask'>57.png
# ./Dataset/<DirEntry 'with_mask'>0_0_10 copy 11.jpg
# ./Dataset/<DirEntry 'with_mask'>58.png
# ./Dataset/<DirEntry 'with_mask'>with_mask014.png
# ./Dataset/<DirEntry 'with_mask'>59.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 68.jpg
# ./Dataset/<DirEntry 'with_mask'>60.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 54.jpg
# ./Dataset/<DirEntry 'with_mask'>61.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 40.jpg
# ./Dataset/<DirEntry 'with_mask'>62.png
# ./Dataset/<DirEntry 'with_mask'>with_mask202.jpg
# ./Dataset/<DirEntry 'with_mask'>63.png
# ./Dataset/<DirEntry 'with_mask'>0_0_16 copy 4.jpg
# ./Dataset/<DirEntry 'with_mask'>64.png
# ./Dataset/<DirEntry 'with_mask'>with_mask216.jpg
# ./Dataset/<DirEntry 'with_mask'>65.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 97.jpg
# ./Dataset/<DirEntry 'with_mask'>66.png
# ./Dataset/<DirEntry 'with_mask'>0_0_21 copy 4.jpg
# ./Dataset/<DirEntry 'with_mask'>67.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 83.jpg
# ./Dataset/<DirEntry 'with_mask'>68.png
# ./Dataset/<DirEntry 'with_mask'>0_0_3 copy 27.jpg
# ./Dataset/<DirEntry 'with_mask'>69.png
# ./Dataset/<DirEntry 'with_mask'>201.jpg
# ./Dataset/<DirEntry 'with_mask'>70.png
# ./Dataset/<DirEntry 'with_mask'>1_1_4 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>71.png
# ./Dataset/<DirEntry 'with_mask'>0_1_26 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>72.png
# ./Dataset/<DirEntry 'with_mask'>0_0_29 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>73.png
# ./Dataset/<DirEntry 'with_mask'>229.jpg
# ./Dataset/<DirEntry 'with_mask'>74.png
# ./Dataset/<DirEntry 'with_mask'>1_0_7 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>75.png
# ./Dataset/<DirEntry 'with_mask'>0_0_2 copy 3.jpg
# ./Dataset/<DirEntry 'with_mask'>76.png
# ./Dataset/<DirEntry 'with_mask'>with_mask028.jpg
# ./Dataset/<DirEntry 'with_mask'>77.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 12.jpg
# ./Dataset/<DirEntry 'with_mask'>78.png
# ./Dataset/<DirEntry 'with_mask'>0_0_9de50022gy1fkizdcyvzaj22kw3vcqv8.jpg
# ./Dataset/<DirEntry 'with_mask'>79.png
# ./Dataset/<DirEntry 'with_mask'>0_0_18 copy 9.jpg
# ./Dataset/<DirEntry 'with_mask'>80.png
# ./Dataset/<DirEntry 'with_mask'>0_0_≈˙◊¢ 2020-02-25 150921.png
# ./Dataset/<DirEntry 'with_mask'>81.png
# ./Dataset/<DirEntry 'with_mask'>1_0_1 copy 9.jpg
# ./Dataset/<DirEntry 'with_mask'>82.png
# ./Dataset/<DirEntry 'with_mask'>349.jpg
# ./Dataset/<DirEntry 'with_mask'>83.png
# ./Dataset/<DirEntry 'with_mask'>with_mask160.jpg
# ./Dataset/<DirEntry 'with_mask'>84.png
# ./Dataset/<DirEntry 'with_mask'>0_0_4 copy 8.jpg
# ./Dataset/<DirEntry 'with_mask'>85.png
# ./Dataset/<DirEntry 'with_mask'>0_0_6 copy 22.jpg
# ./Dataset/<DirEntry 'with_mask'>86.png
# ./Dataset/<DirEntry 'with_mask'>1_0_9.jpg
# ./Dataset/<DirEntry 'with_mask'>87.png
# ./Dataset/<DirEntry 'with_mask'>1_0_682b06c1gy1fr21uc5w9aj20rs15oh75.jpg
# ./Dataset/<DirEntry 'with_mask'>88.png
# ./Dataset/<DirEntry 'with_mask'>with_mask148.jpg
# ./Dataset/<DirEntry 'with_mask'>89.png
# ./Dataset/<DirEntry 'with_mask'>0_0_7 copy 6.jpg
# ./Dataset/<DirEntry 'with_mask'>90.png
# ./Dataset/<DirEntry 'with_mask'>177.jpg
# ./Dataset/<DirEntry 'with_mask'>91.png
# ./Dataset/<DirEntry 'with_mask'>89.jpg
# ./Dataset/<DirEntry 'with_mask'>92.png
# ./Dataset/<DirEntry 'with_mask'>0_0_21.jpg
# ./Dataset/<DirEntry 'with_mask'>93.png
# ./Dataset/<DirEntry 'with_mask'>0_0_35.jpg
# ./Dataset/<DirEntry 'with_mask'>94.png
# ./Dataset/<DirEntry 'with_mask'>163.jpg
# ./Dataset/<DirEntry 'with_mask'>95.png
# ./Dataset/<DirEntry 'with_mask'>1_0_21.jpg
# ./Dataset/<DirEntry 'with_mask'>96.png
# ./Dataset/<DirEntry 'with_mask'>0_0_75889c25ly1fjxx1xgfv2j20u00u041j.jpg
# ./Dataset/<DirEntry 'with_mask'>97.png
# ./Dataset/<DirEntry 'with_mask'>with_mask389.jpg
# ./Dataset/<DirEntry 'with_mask'>98.png
# ./Dataset/<DirEntry 'with_mask'>with_mask376.jpg
# ./Dataset/<DirEntry 'with_mask'>99.png
# ./Dataset/<DirEntry 'with_mask'>with_mask410.jpg
# ./Dataset/<DirEntry 'with_mask'>100.png
# ./Dataset/<DirEntry 'with_mask'>with_mask404.jpg
# ./Dataset/<DirEntry 'with_mask'>101.png
# ./Dataset/<DirEntry 'with_mask'>with_mask362.jpg
# ./Dataset/<DirEntry 'with_mask'>102.png
# ./Dataset/<DirEntry 'with_mask'>0_2_1 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>103.png
# ./Dataset/<DirEntry 'with_mask'>0_0_8 copy 11.jpg
# ./Dataset/<DirEntry 'with_mask'>104.png
# ./Dataset/<DirEntry 'with_mask'>188.jpg
# ./Dataset/<DirEntry 'with_mask'>105.png
# ./Dataset/<DirEntry 'with_mask'>76.jpg
# ./Dataset/<DirEntry 'with_mask'>106.png
# ./Dataset/<DirEntry 'with_mask'>with_mask438.jpg
# ./Dataset/<DirEntry 'with_mask'>107.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy.jpeg
# ./Dataset/<DirEntry 'with_mask'>108.png
# ./Dataset/<DirEntry 'with_mask'>1_0_2 copy 7.jpg
# ./Dataset/<DirEntry 'with_mask'>109.png
# ./Dataset/<DirEntry 'with_mask'>62.jpg
# ./Dataset/<DirEntry 'with_mask'>110.png
# ./Dataset/<DirEntry 'with_mask'>74.jpg
# ./Dataset/<DirEntry 'with_mask'>111.png
# ./Dataset/<DirEntry 'with_mask'>0_0_8 copy 13.jpg
# ./Dataset/<DirEntry 'with_mask'>112.png
# ./Dataset/<DirEntry 'with_mask'>with_mask348.jpg
# ./Dataset/<DirEntry 'with_mask'>113.png
# ./Dataset/<DirEntry 'with_mask'>1_0_6f3feedbly1g35rq8onpcj21400u0tmx.jpg
# ./Dataset/<DirEntry 'with_mask'>114.png
# ./Dataset/<DirEntry 'with_mask'>60.jpg
# ./Dataset/<DirEntry 'with_mask'>115.png
# ./Dataset/<DirEntry 'with_mask'>1_0_2 copy 5.jpg
# ./Dataset/<DirEntry 'with_mask'>116.png
# ./Dataset/<DirEntry 'with_mask'>0_3_663d85a4jw6dd814u9pyfj.jpg
# ./Dataset/<DirEntry 'with_mask'>117.png
# ./Dataset/<DirEntry 'with_mask'>48.jpg
# ./Dataset/<DirEntry 'with_mask'>118.png
# ./Dataset/<DirEntry 'with_mask'>with_mask412.jpg
# ./Dataset/<DirEntry 'with_mask'>119.png
# ./Dataset/<DirEntry 'with_mask'>with_mask374.jpg
# ./Dataset/<DirEntry 'with_mask'>120.png
# ./Dataset/<DirEntry 'with_mask'>1_0_1 copy 3 2.jpg
# ./Dataset/<DirEntry 'with_mask'>121.png
# ./Dataset/<DirEntry 'with_mask'>with_mask360.JPG
# ./Dataset/<DirEntry 'with_mask'>122.png
# ./Dataset/<DirEntry 'with_mask'>with_mask406.jpg
# ./Dataset/<DirEntry 'with_mask'>123.png
# ./Dataset/<DirEntry 'with_mask'>149.jpg
# ./Dataset/<DirEntry 'with_mask'>124.png
# ./Dataset/<DirEntry 'with_mask'>0_0_23.jpg
# ./Dataset/<DirEntry 'with_mask'>125.png
# ./Dataset/<DirEntry 'with_mask'>175.jpg
# ./Dataset/<DirEntry 'with_mask'>126.png
# ./Dataset/<DirEntry 'with_mask'>0_0_7 copy 4.jpg
# ./Dataset/<DirEntry 'with_mask'>127.png
# ./Dataset/<DirEntry 'with_mask'>1_0_23.jpg
# ./Dataset/<DirEntry 'with_mask'>128.png
# ./Dataset/<DirEntry 'with_mask'>161.jpg
# ./Dataset/<DirEntry 'with_mask'>129.png
# ./Dataset/<DirEntry 'with_mask'>0_0_37.jpg
# ./Dataset/<DirEntry 'with_mask'>130.png
# ./Dataset/<DirEntry 'with_mask'>0_0_6 copy 20.jpg
# ./Dataset/<DirEntry 'with_mask'>131.png
# ./Dataset/<DirEntry 'with_mask'>with_mask176.jpg
# ./Dataset/<DirEntry 'with_mask'>132.png
# ./Dataset/<DirEntry 'with_mask'>with_mask162.jpg
# ./Dataset/<DirEntry 'with_mask'>133.png
# ./Dataset/<DirEntry 'with_mask'>with_mask189.jpg
# ./Dataset/<DirEntry 'with_mask'>134.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 38.jpg
# ./Dataset/<DirEntry 'with_mask'>135.png
# ./Dataset/<DirEntry 'with_mask'>0_0_24 copy 3.jpg
# ./Dataset/<DirEntry 'with_mask'>136.png
# ./Dataset/<DirEntry 'with_mask'>0_0_13 copy 3.jpg
# ./Dataset/<DirEntry 'with_mask'>137.png
# ./Dataset/<DirEntry 'with_mask'>0_0_48f333f1gy1gbskbbuciaj20m80m8wlj.jpg
# ./Dataset/<DirEntry 'with_mask'>138.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 10.jpg
# ./Dataset/<DirEntry 'with_mask'>139.png
# ./Dataset/<DirEntry 'with_mask'>1_1_2 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>140.png
# ./Dataset/<DirEntry 'with_mask'>0_1_12 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>141.png
# ./Dataset/<DirEntry 'with_mask'>0_0_4 copy 15.jpg
# ./Dataset/<DirEntry 'with_mask'>142.png
# ./Dataset/<DirEntry 'with_mask'>0_0_74b0deabjw1f8hqhk2j2ij21kw2dc4qp.jpg
# ./Dataset/<DirEntry 'with_mask'>143.png
# ./Dataset/<DirEntry 'with_mask'>with_mask002.jpg
# ./Dataset/<DirEntry 'with_mask'>144.png
# ./Dataset/<DirEntry 'with_mask'>0_0_4 copy 29.jpg
# ./Dataset/<DirEntry 'with_mask'>145.png
# ./Dataset/<DirEntry 'with_mask'>0_0_9 copy 9.jpg
# ./Dataset/<DirEntry 'with_mask'>146.png
# ./Dataset/<DirEntry 'with_mask'>with_mask016.jpg
# ./Dataset/<DirEntry 'with_mask'>147.png
# ./Dataset/<DirEntry 'with_mask'>0_0_46fe0b54jw1eysjnlcazwj20dc0hsac0.jpg
# ./Dataset/<DirEntry 'with_mask'>148.png
# ./Dataset/<DirEntry 'with_mask'>0_0_3 copy 19.jpg
# ./Dataset/<DirEntry 'with_mask'>149.png
# ./Dataset/<DirEntry 'with_mask'>203.jpg
# ./Dataset/<DirEntry 'with_mask'>150.png
# ./Dataset/<DirEntry 'with_mask'>0_0_3 copy 25.jpg
# ./Dataset/<DirEntry 'with_mask'>151.png
# ./Dataset/<DirEntry 'with_mask'>0_1_7 copy 3.jpg
# ./Dataset/<DirEntry 'with_mask'>152.png
# ./Dataset/<DirEntry 'with_mask'>0_0_3 copy 31.jpg
# ./Dataset/<DirEntry 'with_mask'>153.png
# ./Dataset/<DirEntry 'with_mask'>217.jpg
# ./Dataset/<DirEntry 'with_mask'>154.png
# ./Dataset/<DirEntry 'with_mask'>0_0_15 copy 8.jpg
# ./Dataset/<DirEntry 'with_mask'>155.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 95.jpg
# ./Dataset/<DirEntry 'with_mask'>156.png
# ./Dataset/<DirEntry 'with_mask'>with_mask228.jpg
# ./Dataset/<DirEntry 'with_mask'>157.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 81.jpg
# ./Dataset/<DirEntry 'with_mask'>158.png
# ./Dataset/<DirEntry 'with_mask'>0_0_21 copy 6.jpg
# ./Dataset/<DirEntry 'with_mask'>159.png
# ./Dataset/<DirEntry 'with_mask'>0_0_16 copy 6.jpg
# ./Dataset/<DirEntry 'with_mask'>160.png
# ./Dataset/<DirEntry 'with_mask'>with_mask200.jpg
# ./Dataset/<DirEntry 'with_mask'>161.png
# ./Dataset/<DirEntry 'with_mask'>with_mask214.jpg
# ./Dataset/<DirEntry 'with_mask'>162.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 56.jpg
# ./Dataset/<DirEntry 'with_mask'>163.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 42.jpg
# ./Dataset/<DirEntry 'with_mask'>164.png
# ./Dataset/<DirEntry 'with_mask'>0_0_10 copy 13.jpg
# ./Dataset/<DirEntry 'with_mask'>165.png
# ./Dataset/<DirEntry 'with_mask'>0_1_0.jpeg
# ./Dataset/<DirEntry 'with_mask'>166.png
# ./Dataset/<DirEntry 'with_mask'>0_0_10 copy 12.jpg
# ./Dataset/<DirEntry 'with_mask'>167.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 43.jpg
# ./Dataset/<DirEntry 'with_mask'>168.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 57.jpg
# ./Dataset/<DirEntry 'with_mask'>169.png
# ./Dataset/<DirEntry 'with_mask'>with_mask215.jpg
# ./Dataset/<DirEntry 'with_mask'>170.png
# ./Dataset/<DirEntry 'with_mask'>0_0_16 copy 7.jpg
# ./Dataset/<DirEntry 'with_mask'>171.png
# ./Dataset/<DirEntry 'with_mask'>with_mask201.jpg
# ./Dataset/<DirEntry 'with_mask'>172.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 80.jpg
# ./Dataset/<DirEntry 'with_mask'>173.png
# ./Dataset/<DirEntry 'with_mask'>0_0_21 copy 7.jpg
# ./Dataset/<DirEntry 'with_mask'>174.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 94.jpg
# ./Dataset/<DirEntry 'with_mask'>175.png
# ./Dataset/<DirEntry 'with_mask'>0_0_3 copy 30.jpg
# ./Dataset/<DirEntry 'with_mask'>176.png
# ./Dataset/<DirEntry 'with_mask'>216.jpg
# ./Dataset/<DirEntry 'with_mask'>177.png
# ./Dataset/<DirEntry 'with_mask'>202.jpg
# ./Dataset/<DirEntry 'with_mask'>178.png
# ./Dataset/<DirEntry 'with_mask'>0_0_3 copy 18.jpg
# ./Dataset/<DirEntry 'with_mask'>179.png
# ./Dataset/<DirEntry 'with_mask'>with_mask017.jpg
# ./Dataset/<DirEntry 'with_mask'>180.png
# ./Dataset/<DirEntry 'with_mask'>with_mask003.jpg
# ./Dataset/<DirEntry 'with_mask'>181.png
# ./Dataset/<DirEntry 'with_mask'>0_0_9 copy 8.jpg
# ./Dataset/<DirEntry 'with_mask'>182.png
# ./Dataset/<DirEntry 'with_mask'>0_0_4 copy 28.jpg
# ./Dataset/<DirEntry 'with_mask'>183.png
# ./Dataset/<DirEntry 'with_mask'>0_0_4 copy 14.jpg
# ./Dataset/<DirEntry 'with_mask'>184.png
# ./Dataset/<DirEntry 'with_mask'>0_0_13 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>185.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 11.jpg
# ./Dataset/<DirEntry 'with_mask'>186.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 39.jpg
# ./Dataset/<DirEntry 'with_mask'>187.png
# ./Dataset/<DirEntry 'with_mask'>0_0_24 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>188.png
# ./Dataset/<DirEntry 'with_mask'>with_mask188.jpg
# ./Dataset/<DirEntry 'with_mask'>189.png
# ./Dataset/<DirEntry 'with_mask'>with_mask163.jpg
# ./Dataset/<DirEntry 'with_mask'>190.png
# ./Dataset/<DirEntry 'with_mask'>with_mask177.jpg
# ./Dataset/<DirEntry 'with_mask'>191.png
# ./Dataset/<DirEntry 'with_mask'>0_0_006LvDhLly1g790l6riuhj30hs0pntab.jpg
# ./Dataset/<DirEntry 'with_mask'>192.png
# ./Dataset/<DirEntry 'with_mask'>0_0_6b064143ly1gb8tr8w2q7j20zk1hcduo.jpg
# ./Dataset/<DirEntry 'with_mask'>193.png
# ./Dataset/<DirEntry 'with_mask'>160.jpg
# ./Dataset/<DirEntry 'with_mask'>194.png
# ./Dataset/<DirEntry 'with_mask'>1_0_22.jpg
# ./Dataset/<DirEntry 'with_mask'>195.png
# ./Dataset/<DirEntry 'with_mask'>0_0_36.jpg
# ./Dataset/<DirEntry 'with_mask'>196.png
# ./Dataset/<DirEntry 'with_mask'>0_0_22.jpg
# ./Dataset/<DirEntry 'with_mask'>197.png
# ./Dataset/<DirEntry 'with_mask'>0_0_7 copy 5.jpg
# ./Dataset/<DirEntry 'with_mask'>198.png
# ./Dataset/<DirEntry 'with_mask'>174.jpg
# ./Dataset/<DirEntry 'with_mask'>199.png
# ./Dataset/<DirEntry 'with_mask'>0_0_10 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>200.png
# ./Dataset/<DirEntry 'with_mask'>0_0_11 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>201.png
# ./Dataset/<DirEntry 'with_mask'>0_2_1 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>202.png
# ./Dataset/<DirEntry 'with_mask'>148.jpg
# ./Dataset/<DirEntry 'with_mask'>203.png
# ./Dataset/<DirEntry 'with_mask'>with_mask361.jpg
# ./Dataset/<DirEntry 'with_mask'>204.png
# ./Dataset/<DirEntry 'with_mask'>with_mask407.jpg
# ./Dataset/<DirEntry 'with_mask'>205.png
# ./Dataset/<DirEntry 'with_mask'>1_0_7 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>206.png
# ./Dataset/<DirEntry 'with_mask'>with_mask413.jpg
# ./Dataset/<DirEntry 'with_mask'>207.png
# ./Dataset/<DirEntry 'with_mask'>49.jpg
# ./Dataset/<DirEntry 'with_mask'>208.png
# ./Dataset/<DirEntry 'with_mask'>with_mask375.jpg
# ./Dataset/<DirEntry 'with_mask'>209.png
# ./Dataset/<DirEntry 'with_mask'>1_0_2 copy 4.jpg
# ./Dataset/<DirEntry 'with_mask'>210.png
# ./Dataset/<DirEntry 'with_mask'>75.jpg
# ./Dataset/<DirEntry 'with_mask'>211.png
# ./Dataset/<DirEntry 'with_mask'>with_mask349.jpg
# ./Dataset/<DirEntry 'with_mask'>212.png
# ./Dataset/<DirEntry 'with_mask'>0_0_8 copy 12.jpg
# ./Dataset/<DirEntry 'with_mask'>213.png
# ./Dataset/<DirEntry 'with_mask'>with_mask371.jpg
# ./Dataset/<DirEntry 'with_mask'>214.png
# ./Dataset/<DirEntry 'with_mask'>with_mask417.jpg
# ./Dataset/<DirEntry 'with_mask'>215.png
# ./Dataset/<DirEntry 'with_mask'>with_mask403.jpg
# ./Dataset/<DirEntry 'with_mask'>216.png
# ./Dataset/<DirEntry 'with_mask'>59.jpg
# ./Dataset/<DirEntry 'with_mask'>217.png
# ./Dataset/<DirEntry 'with_mask'>with_mask365.jpg
# ./Dataset/<DirEntry 'with_mask'>218.png
# ./Dataset/<DirEntry 'with_mask'>0_0_8 copy 16.jpg
# ./Dataset/<DirEntry 'with_mask'>219.png
# ./Dataset/<DirEntry 'with_mask'>71.jpg
# ./Dataset/<DirEntry 'with_mask'>220.png
# ./Dataset/<DirEntry 'with_mask'>65.jpg
# ./Dataset/<DirEntry 'with_mask'>221.png
# ./Dataset/<DirEntry 'with_mask'>with_mask359.jpg
# ./Dataset/<DirEntry 'with_mask'>222.png
# ./Dataset/<DirEntry 'with_mask'>170.jpg
# ./Dataset/<DirEntry 'with_mask'>223.png
# ./Dataset/<DirEntry 'with_mask'>0_1_4 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>224.png
# ./Dataset/<DirEntry 'with_mask'>0_0_26.jpg
# ./Dataset/<DirEntry 'with_mask'>225.png
# ./Dataset/<DirEntry 'with_mask'>0_0_32.jpg
# ./Dataset/<DirEntry 'with_mask'>226.png
# ./Dataset/<DirEntry 'with_mask'>0_1_5 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>227.png
# ./Dataset/<DirEntry 'with_mask'>164.jpg
# ./Dataset/<DirEntry 'with_mask'>228.png
# ./Dataset/<DirEntry 'with_mask'>158.jpg
# ./Dataset/<DirEntry 'with_mask'>229.png
# ./Dataset/<DirEntry 'with_mask'>0_0_6 copy 19.jpg
# ./Dataset/<DirEntry 'with_mask'>230.png
# ./Dataset/<DirEntry 'with_mask'>with_mask173.jpg
# ./Dataset/<DirEntry 'with_mask'>231.png
# ./Dataset/<DirEntry 'with_mask'>with_mask167.jpg
# ./Dataset/<DirEntry 'with_mask'>232.png
# ./Dataset/<DirEntry 'with_mask'>0_2_9.jpg
# ./Dataset/<DirEntry 'with_mask'>233.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 15.jpg
# ./Dataset/<DirEntry 'with_mask'>234.png
# ./Dataset/<DirEntry 'with_mask'>0_0_13 copy 6.jpg
# ./Dataset/<DirEntry 'with_mask'>235.png
# ./Dataset/<DirEntry 'with_mask'>1_0_14 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>236.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 2 2.jpg
# ./Dataset/<DirEntry 'with_mask'>237.png
# ./Dataset/<DirEntry 'with_mask'>1_0_15 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>238.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 29.jpg
# ./Dataset/<DirEntry 'with_mask'>239.png
# ./Dataset/<DirEntry 'with_mask'>with_mask198.jpg
# ./Dataset/<DirEntry 'with_mask'>240.png
# ./Dataset/<DirEntry 'with_mask'>0_0_24 copy 6.jpg
# ./Dataset/<DirEntry 'with_mask'>241.png
# ./Dataset/<DirEntry 'with_mask'>0_0_2 copy 4.jpg
# ./Dataset/<DirEntry 'with_mask'>242.png
# ./Dataset/<DirEntry 'with_mask'>with_mask007.jpg
# ./Dataset/<DirEntry 'with_mask'>243.png
# ./Dataset/<DirEntry 'with_mask'>with_mask013.jpg
# ./Dataset/<DirEntry 'with_mask'>244.png
# ./Dataset/<DirEntry 'with_mask'>0_0_4 copy 10.jpg
# ./Dataset/<DirEntry 'with_mask'>245.png
# ./Dataset/<DirEntry 'with_mask'>1_0_4d086e061d950a7bf14c94e17f73a8dcf3d3c9c7.jpeg
# ./Dataset/<DirEntry 'with_mask'>246.png
# ./Dataset/<DirEntry 'with_mask'>0_0_3 copy 20.jpg
# ./Dataset/<DirEntry 'with_mask'>247.png
# ./Dataset/<DirEntry 'with_mask'>206.jpg
# ./Dataset/<DirEntry 'with_mask'>248.png
# ./Dataset/<DirEntry 'with_mask'>212.jpg
# ./Dataset/<DirEntry 'with_mask'>249.png
# ./Dataset/<DirEntry 'with_mask'>0_0_3 copy 34.jpg
# ./Dataset/<DirEntry 'with_mask'>250.png
# ./Dataset/<DirEntry 'with_mask'>with_mask205.jpg
# ./Dataset/<DirEntry 'with_mask'>251.png
# ./Dataset/<DirEntry 'with_mask'>0_0_16 copy 3.jpg
# ./Dataset/<DirEntry 'with_mask'>252.png
# ./Dataset/<DirEntry 'with_mask'>with_mask211.jpg
# ./Dataset/<DirEntry 'with_mask'>253.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 90.jpg
# ./Dataset/<DirEntry 'with_mask'>254.png
# ./Dataset/<DirEntry 'with_mask'>0_0_33 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>255.png
# ./Dataset/<DirEntry 'with_mask'>with_mask239.jpg
# ./Dataset/<DirEntry 'with_mask'>256.png
# ./Dataset/<DirEntry 'with_mask'>0_0_21 copy 3.jpg
# ./Dataset/<DirEntry 'with_mask'>257.png
# ./Dataset/<DirEntry 'with_mask'>0_0_32 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>258.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 84.jpg
# ./Dataset/<DirEntry 'with_mask'>259.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 53.jpg
# ./Dataset/<DirEntry 'with_mask'>260.png
# ./Dataset/<DirEntry 'with_mask'>0_0_≈˙◊¢ 2020-02-23 132400.png
# ./Dataset/<DirEntry 'with_mask'>261.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 47.jpg
# ./Dataset/<DirEntry 'with_mask'>262.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 46.jpg
# ./Dataset/<DirEntry 'with_mask'>263.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 52.jpg
# ./Dataset/<DirEntry 'with_mask'>264.png
# ./Dataset/<DirEntry 'with_mask'>1_2_22.jpg
# ./Dataset/<DirEntry 'with_mask'>265.png
# ./Dataset/<DirEntry 'with_mask'>0_0_21 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>266.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 85.jpg
# ./Dataset/<DirEntry 'with_mask'>267.png
# ./Dataset/<DirEntry 'with_mask'>with_mask238.jpg
# ./Dataset/<DirEntry 'with_mask'>268.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 91.jpg
# ./Dataset/<DirEntry 'with_mask'>269.png
# ./Dataset/<DirEntry 'with_mask'>with_mask210.jpg
# ./Dataset/<DirEntry 'with_mask'>270.png
# ./Dataset/<DirEntry 'with_mask'>with_mask204.jpg
# ./Dataset/<DirEntry 'with_mask'>271.png
# ./Dataset/<DirEntry 'with_mask'>0_0_16 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>272.png
# ./Dataset/<DirEntry 'with_mask'>0_0_≈˙◊¢ 2020-02-24 202509.png
# ./Dataset/<DirEntry 'with_mask'>273.png
# ./Dataset/<DirEntry 'with_mask'>0_0_≈˙◊¢ 2020-02-25 150847.png
# ./Dataset/<DirEntry 'with_mask'>274.png
# ./Dataset/<DirEntry 'with_mask'>213.jpg
# ./Dataset/<DirEntry 'with_mask'>275.png
# ./Dataset/<DirEntry 'with_mask'>0_0_3 copy 21.jpg
# ./Dataset/<DirEntry 'with_mask'>276.png
# ./Dataset/<DirEntry 'with_mask'>207.jpg
# ./Dataset/<DirEntry 'with_mask'>277.png
# ./Dataset/<DirEntry 'with_mask'>0_0_45 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>278.png
# ./Dataset/<DirEntry 'with_mask'>0_0_4 copy 11.jpg
# ./Dataset/<DirEntry 'with_mask'>279.png
# ./Dataset/<DirEntry 'with_mask'>1_0_Img256749801.jpg
# ./Dataset/<DirEntry 'with_mask'>280.png
# ./Dataset/<DirEntry 'with_mask'>with_mask012.jpg
# ./Dataset/<DirEntry 'with_mask'>281.png
# ./Dataset/<DirEntry 'with_mask'>0_0_2 copy 5.jpg
# ./Dataset/<DirEntry 'with_mask'>282.png
# ./Dataset/<DirEntry 'with_mask'>with_mask006.jpg
# ./Dataset/<DirEntry 'with_mask'>283.png
# ./Dataset/<DirEntry 'with_mask'>0_0_24 copy 7.jpg
# ./Dataset/<DirEntry 'with_mask'>284.png
# ./Dataset/<DirEntry 'with_mask'>with_mask199.jpg
# ./Dataset/<DirEntry 'with_mask'>285.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 28.jpg
# ./Dataset/<DirEntry 'with_mask'>286.png
# ./Dataset/<DirEntry 'with_mask'>1_0_0075etYcly1ftg5jvmnamj322o3407f5.jpg
# ./Dataset/<DirEntry 'with_mask'>287.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 14.jpg
# ./Dataset/<DirEntry 'with_mask'>288.png
# ./Dataset/<DirEntry 'with_mask'>1_0_006LvDhLly1g790l6enetj30hs0pidh3.jpg
# ./Dataset/<DirEntry 'with_mask'>289.png
# ./Dataset/<DirEntry 'with_mask'>0_0_13 copy 7.jpg
# ./Dataset/<DirEntry 'with_mask'>290.png
# ./Dataset/<DirEntry 'with_mask'>with_mask166.jpg
# ./Dataset/<DirEntry 'with_mask'>291.png
# ./Dataset/<DirEntry 'with_mask'>0_0_6 copy 18.jpg
# ./Dataset/<DirEntry 'with_mask'>292.png
# ./Dataset/<DirEntry 'with_mask'>with_mask172.jpg
# ./Dataset/<DirEntry 'with_mask'>293.png
# ./Dataset/<DirEntry 'with_mask'>159.jpg
# ./Dataset/<DirEntry 'with_mask'>294.png
# ./Dataset/<DirEntry 'with_mask'>0_0_33.jpg
# ./Dataset/<DirEntry 'with_mask'>295.png
# ./Dataset/<DirEntry 'with_mask'>165.jpg
# ./Dataset/<DirEntry 'with_mask'>296.png
# ./Dataset/<DirEntry 'with_mask'>0_0_4a1f9f75ly1gbsiwdi2axj20mm0lwtgn.jpg
# ./Dataset/<DirEntry 'with_mask'>297.png
# ./Dataset/<DirEntry 'with_mask'>1_0_27.jpg
# ./Dataset/<DirEntry 'with_mask'>298.png
# ./Dataset/<DirEntry 'with_mask'>1_0_33.jpg
# ./Dataset/<DirEntry 'with_mask'>299.png
# ./Dataset/<DirEntry 'with_mask'>171.jpg
# ./Dataset/<DirEntry 'with_mask'>300.png
# ./Dataset/<DirEntry 'with_mask'>0_0_27.jpg
# ./Dataset/<DirEntry 'with_mask'>301.png
# ./Dataset/<DirEntry 'with_mask'>64.jpg
# ./Dataset/<DirEntry 'with_mask'>302.png
# ./Dataset/<DirEntry 'with_mask'>with_mask358.jpg
# ./Dataset/<DirEntry 'with_mask'>303.png
# ./Dataset/<DirEntry 'with_mask'>0_0_8 copy 17.jpg
# ./Dataset/<DirEntry 'with_mask'>304.png
# ./Dataset/<DirEntry 'with_mask'>70.jpg
# ./Dataset/<DirEntry 'with_mask'>305.png
# ./Dataset/<DirEntry 'with_mask'>58.jpg
# ./Dataset/<DirEntry 'with_mask'>306.png
# ./Dataset/<DirEntry 'with_mask'>0_0_10 copy 9.jpg
# ./Dataset/<DirEntry 'with_mask'>307.png
# ./Dataset/<DirEntry 'with_mask'>with_mask402.jpg
# ./Dataset/<DirEntry 'with_mask'>308.png
# ./Dataset/<DirEntry 'with_mask'>with_mask364.jpg
# ./Dataset/<DirEntry 'with_mask'>309.png
# ./Dataset/<DirEntry 'with_mask'>0_1_2 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>310.png
# ./Dataset/<DirEntry 'with_mask'>with_mask370.jpg
# ./Dataset/<DirEntry 'with_mask'>311.png
# ./Dataset/<DirEntry 'with_mask'>with_mask416.jpg
# ./Dataset/<DirEntry 'with_mask'>312.png
# ./Dataset/<DirEntry 'with_mask'>1_0_9de50022gy1fkizdl3o16j22kw3vcu12.jpg
# ./Dataset/<DirEntry 'with_mask'>313.png
# ./Dataset/<DirEntry 'with_mask'>with_mask366.jpg
# ./Dataset/<DirEntry 'with_mask'>314.png
# ./Dataset/<DirEntry 'with_mask'>8.jpg
# ./Dataset/<DirEntry 'with_mask'>315.png
# ./Dataset/<DirEntry 'with_mask'>1_0_11 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>316.png
# ./Dataset/<DirEntry 'with_mask'>with_mask400.jpg
# ./Dataset/<DirEntry 'with_mask'>317.png
# ./Dataset/<DirEntry 'with_mask'>with_mask414.jpg
# ./Dataset/<DirEntry 'with_mask'>318.png
# ./Dataset/<DirEntry 'with_mask'>with_mask372.jpg
# ./Dataset/<DirEntry 'with_mask'>319.png
# ./Dataset/<DirEntry 'with_mask'>198.jpg
# ./Dataset/<DirEntry 'with_mask'>320.png
# ./Dataset/<DirEntry 'with_mask'>66.jpg
# ./Dataset/<DirEntry 'with_mask'>321.png
# ./Dataset/<DirEntry 'with_mask'>1_0_2 copy 3.jpg
# ./Dataset/<DirEntry 'with_mask'>322.png
# ./Dataset/<DirEntry 'with_mask'>0_0_8.jpg
# ./Dataset/<DirEntry 'with_mask'>323.png
# ./Dataset/<DirEntry 'with_mask'>with_mask428.jpg
# ./Dataset/<DirEntry 'with_mask'>324.png
# ./Dataset/<DirEntry 'with_mask'>72.jpg
# ./Dataset/<DirEntry 'with_mask'>325.png
# ./Dataset/<DirEntry 'with_mask'>0_0_8 copy 15.jpg
# ./Dataset/<DirEntry 'with_mask'>326.png
# ./Dataset/<DirEntry 'with_mask'>1_0_25.jpg
# ./Dataset/<DirEntry 'with_mask'>327.png
# ./Dataset/<DirEntry 'with_mask'>167.jpg
# ./Dataset/<DirEntry 'with_mask'>328.png
# ./Dataset/<DirEntry 'with_mask'>0_0_31.jpg
# ./Dataset/<DirEntry 'with_mask'>329.png
# ./Dataset/<DirEntry 'with_mask'>99.jpg
# ./Dataset/<DirEntry 'with_mask'>330.png
# ./Dataset/<DirEntry 'with_mask'>0_0_25.jpg
# ./Dataset/<DirEntry 'with_mask'>331.png
# ./Dataset/<DirEntry 'with_mask'>0_0_7 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>332.png
# ./Dataset/<DirEntry 'with_mask'>173.jpg
# ./Dataset/<DirEntry 'with_mask'>333.png
# ./Dataset/<DirEntry 'with_mask'>1_0_19.jpg
# ./Dataset/<DirEntry 'with_mask'>334.png
# ./Dataset/<DirEntry 'with_mask'>with_mask399.jpg
# ./Dataset/<DirEntry 'with_mask'>335.png
# ./Dataset/<DirEntry 'with_mask'>0_0_19.jpg
# ./Dataset/<DirEntry 'with_mask'>336.png
# ./Dataset/<DirEntry 'with_mask'>with_mask164.jpg
# ./Dataset/<DirEntry 'with_mask'>337.png
# ./Dataset/<DirEntry 'with_mask'>0_1_18 copy 3.jpg
# ./Dataset/<DirEntry 'with_mask'>338.png
# ./Dataset/<DirEntry 'with_mask'>with_mask170.jpg
# ./Dataset/<DirEntry 'with_mask'>339.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0075etYcly1ftg5jweo23j328e34014y.jpg
# ./Dataset/<DirEntry 'with_mask'>340.png
# ./Dataset/<DirEntry 'with_mask'>with_mask158.jpg
# ./Dataset/<DirEntry 'with_mask'>341.png
# ./Dataset/<DirEntry 'with_mask'>1_0_20160215005358_5MLQK.jpeg
# ./Dataset/<DirEntry 'with_mask'>342.png
# ./Dataset/<DirEntry 'with_mask'>0_0_13 copy 5.jpg
# ./Dataset/<DirEntry 'with_mask'>343.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 16.jpg
# ./Dataset/<DirEntry 'with_mask'>344.png
# ./Dataset/<DirEntry 'with_mask'>0_2_ab41fce2gy1fyq9sp8l7rj223u35sx6p.jpg
# ./Dataset/<DirEntry 'with_mask'>345.png
# ./Dataset/<DirEntry 'with_mask'>0_0_24 copy 5.jpg
# ./Dataset/<DirEntry 'with_mask'>346.png
# ./Dataset/<DirEntry 'with_mask'>0_0_6 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>347.png
# ./Dataset/<DirEntry 'with_mask'>with_mask010.jpg
# ./Dataset/<DirEntry 'with_mask'>348.png
# ./Dataset/<DirEntry 'with_mask'>0_0_7 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>349.png
# ./Dataset/<DirEntry 'with_mask'>with_mask004.jpg
# ./Dataset/<DirEntry 'with_mask'>350.png
# ./Dataset/<DirEntry 'with_mask'>0_0_2 copy 7.jpg
# ./Dataset/<DirEntry 'with_mask'>351.png
# ./Dataset/<DirEntry 'with_mask'>with_mask038.jpg
# ./Dataset/<DirEntry 'with_mask'>352.png
# ./Dataset/<DirEntry 'with_mask'>0_0_4 copy 13.jpg
# ./Dataset/<DirEntry 'with_mask'>353.png
# ./Dataset/<DirEntry 'with_mask'>1_1_663d85a4jw6dd814u9pyfj.jpg
# ./Dataset/<DirEntry 'with_mask'>354.png
# ./Dataset/<DirEntry 'with_mask'>211.jpg
# ./Dataset/<DirEntry 'with_mask'>355.png
# ./Dataset/<DirEntry 'with_mask'>205.jpg
# ./Dataset/<DirEntry 'with_mask'>356.png
# ./Dataset/<DirEntry 'with_mask'>0_0_3 copy 23.jpg
# ./Dataset/<DirEntry 'with_mask'>357.png
# ./Dataset/<DirEntry 'with_mask'>239.jpg
# ./Dataset/<DirEntry 'with_mask'>358.png
# ./Dataset/<DirEntry 'with_mask'>with_mask212.jpg
# ./Dataset/<DirEntry 'with_mask'>359.png
# ./Dataset/<DirEntry 'with_mask'>with_mask206.jpg
# ./Dataset/<DirEntry 'with_mask'>360.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 87.jpg
# ./Dataset/<DirEntry 'with_mask'>361.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 93.jpg
# ./Dataset/<DirEntry 'with_mask'>362.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 9.jpg
# ./Dataset/<DirEntry 'with_mask'>363.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 78.jpg
# ./Dataset/<DirEntry 'with_mask'>364.png
# ./Dataset/<DirEntry 'with_mask'>0_0_10 copy 15.jpg
# ./Dataset/<DirEntry 'with_mask'>365.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 44.jpg
# ./Dataset/<DirEntry 'with_mask'>366.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 50.jpg
# ./Dataset/<DirEntry 'with_mask'>367.png
# ./Dataset/<DirEntry 'with_mask'>0_0_006ajtxFly1g5eb2w437yj30jn0ojta1.jpg
# ./Dataset/<DirEntry 'with_mask'>368.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 51.jpg
# ./Dataset/<DirEntry 'with_mask'>369.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 45.jpg
# ./Dataset/<DirEntry 'with_mask'>370.png
# ./Dataset/<DirEntry 'with_mask'>0_1_973cb0eaa26b80d86d9c49008c84c844.jpg
# ./Dataset/<DirEntry 'with_mask'>371.png
# ./Dataset/<DirEntry 'with_mask'>0_2_21.jpg
# ./Dataset/<DirEntry 'with_mask'>372.png
# ./Dataset/<DirEntry 'with_mask'>0_0_10 copy 14.jpg
# ./Dataset/<DirEntry 'with_mask'>373.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 8.jpg
# ./Dataset/<DirEntry 'with_mask'>374.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 79.jpg
# ./Dataset/<DirEntry 'with_mask'>375.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 92.jpg
# ./Dataset/<DirEntry 'with_mask'>376.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 86.jpg
# ./Dataset/<DirEntry 'with_mask'>377.png
# ./Dataset/<DirEntry 'with_mask'>with_mask207.jpg
# ./Dataset/<DirEntry 'with_mask'>378.png
# ./Dataset/<DirEntry 'with_mask'>with_mask213.jpg
# ./Dataset/<DirEntry 'with_mask'>379.png
# ./Dataset/<DirEntry 'with_mask'>0_0_ab41fce2gy1fyq9suyy45j223u35sx6p.jpg
# ./Dataset/<DirEntry 'with_mask'>380.png
# ./Dataset/<DirEntry 'with_mask'>238.jpg
# ./Dataset/<DirEntry 'with_mask'>381.png
# ./Dataset/<DirEntry 'with_mask'>204.jpg
# ./Dataset/<DirEntry 'with_mask'>382.png
# ./Dataset/<DirEntry 'with_mask'>0_0_3 copy 22.jpg
# ./Dataset/<DirEntry 'with_mask'>383.png
# ./Dataset/<DirEntry 'with_mask'>210.jpg
# ./Dataset/<DirEntry 'with_mask'>384.png
# ./Dataset/<DirEntry 'with_mask'>with_mask039.jpg
# ./Dataset/<DirEntry 'with_mask'>385.png
# ./Dataset/<DirEntry 'with_mask'>0_0_4 copy 12.jpg
# ./Dataset/<DirEntry 'with_mask'>386.png
# ./Dataset/<DirEntry 'with_mask'>with_mask005.jpg
# ./Dataset/<DirEntry 'with_mask'>387.png
# ./Dataset/<DirEntry 'with_mask'>0_0_2 copy 6.jpg
# ./Dataset/<DirEntry 'with_mask'>388.png
# ./Dataset/<DirEntry 'with_mask'>1_0_≈˙◊¢ 2020-02-24 202935.png
# ./Dataset/<DirEntry 'with_mask'>389.png
# ./Dataset/<DirEntry 'with_mask'>with_mask011.jpg
# ./Dataset/<DirEntry 'with_mask'>390.png
# ./Dataset/<DirEntry 'with_mask'>358.jpg
# ./Dataset/<DirEntry 'with_mask'>391.png
# ./Dataset/<DirEntry 'with_mask'>0_0_24 copy 4.jpg
# ./Dataset/<DirEntry 'with_mask'>392.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy 17.jpg
# ./Dataset/<DirEntry 'with_mask'>393.png
# ./Dataset/<DirEntry 'with_mask'>with_mask159.jpg
# ./Dataset/<DirEntry 'with_mask'>394.png
# ./Dataset/<DirEntry 'with_mask'>with_mask171.jpg
# ./Dataset/<DirEntry 'with_mask'>395.png
# ./Dataset/<DirEntry 'with_mask'>1_0_20 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>396.png
# ./Dataset/<DirEntry 'with_mask'>0_0_5495a3d7gy1gaph1hi8cuj22yo1o0qv5.jpg
# ./Dataset/<DirEntry 'with_mask'>397.png
# ./Dataset/<DirEntry 'with_mask'>0_1_18 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>398.png
# ./Dataset/<DirEntry 'with_mask'>1_0_21 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>399.png
# ./Dataset/<DirEntry 'with_mask'>0_0_18.jpg
# ./Dataset/<DirEntry 'with_mask'>400.png
# ./Dataset/<DirEntry 'with_mask'>with_mask398.jpg
# ./Dataset/<DirEntry 'with_mask'>401.png
# ./Dataset/<DirEntry 'with_mask'>1_0_18.jpg
# ./Dataset/<DirEntry 'with_mask'>402.png
# ./Dataset/<DirEntry 'with_mask'>0_0_24.jpg
# ./Dataset/<DirEntry 'with_mask'>403.png
# ./Dataset/<DirEntry 'with_mask'>172.jpg
# ./Dataset/<DirEntry 'with_mask'>404.png
# ./Dataset/<DirEntry 'with_mask'>0_0_7 copy 3.jpg
# ./Dataset/<DirEntry 'with_mask'>405.png
# ./Dataset/<DirEntry 'with_mask'>166.jpg
# ./Dataset/<DirEntry 'with_mask'>406.png
# ./Dataset/<DirEntry 'with_mask'>1_0_24.jpg
# ./Dataset/<DirEntry 'with_mask'>407.png
# ./Dataset/<DirEntry 'with_mask'>98.jpg
# ./Dataset/<DirEntry 'with_mask'>408.png
# ./Dataset/<DirEntry 'with_mask'>0_0_30.jpg
# ./Dataset/<DirEntry 'with_mask'>409.png
# ./Dataset/<DirEntry 'with_mask'>73.jpg
# ./Dataset/<DirEntry 'with_mask'>410.png
# ./Dataset/<DirEntry 'with_mask'>with_mask429.jpg
# ./Dataset/<DirEntry 'with_mask'>411.png
# ./Dataset/<DirEntry 'with_mask'>0_0_8 copy 14.jpg
# ./Dataset/<DirEntry 'with_mask'>412.png
# ./Dataset/<DirEntry 'with_mask'>0_0_9.jpg
# ./Dataset/<DirEntry 'with_mask'>413.png
# ./Dataset/<DirEntry 'with_mask'>1_0_2 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>414.png
# ./Dataset/<DirEntry 'with_mask'>67.jpg
# ./Dataset/<DirEntry 'with_mask'>415.png
# ./Dataset/<DirEntry 'with_mask'>with_mask415.jpg
# ./Dataset/<DirEntry 'with_mask'>416.png
# ./Dataset/<DirEntry 'with_mask'>with_mask373.jpg
# ./Dataset/<DirEntry 'with_mask'>417.png
# ./Dataset/<DirEntry 'with_mask'>9.jpg
# ./Dataset/<DirEntry 'with_mask'>418.png
# ./Dataset/<DirEntry 'with_mask'>with_mask367.jpg
# ./Dataset/<DirEntry 'with_mask'>419.png
# ./Dataset/<DirEntry 'with_mask'>with_mask401.jpg
# ./Dataset/<DirEntry 'with_mask'>420.png
# ./Dataset/<DirEntry 'with_mask'>1_0_11 copy 3.jpg
# ./Dataset/<DirEntry 'with_mask'>421.png
# ./Dataset/<DirEntry 'with_mask'>1_0_0075etYcly1ftg5jx5binj31vr340dr6.jpg
# ./Dataset/<DirEntry 'with_mask'>422.png
# ./Dataset/<DirEntry 'with_mask'>14.jpg
# ./Dataset/<DirEntry 'with_mask'>423.png
# ./Dataset/<DirEntry 'with_mask'>with_mask328.jpg
# ./Dataset/<DirEntry 'with_mask'>424.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0066ntrkgw1f8lreziaalj30iw0cl40h.jpg
# ./Dataset/<DirEntry 'with_mask'>425.png
# ./Dataset/<DirEntry 'with_mask'>with_mask300.jpg
# ./Dataset/<DirEntry 'with_mask'>426.png
# ./Dataset/<DirEntry 'with_mask'>0_0_8 copy 5.jpg
# ./Dataset/<DirEntry 'with_mask'>427.png
# ./Dataset/<DirEntry 'with_mask'>0_0_5 copy 27.jpg
# ./Dataset/<DirEntry 'with_mask'>428.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 3.png
# ./Dataset/<DirEntry 'with_mask'>429.png
# ./Dataset/<DirEntry 'with_mask'>with_mask466.jpg
# ./Dataset/<DirEntry 'with_mask'>430.png
# ./Dataset/<DirEntry 'with_mask'>with_mask472.jpg
# ./Dataset/<DirEntry 'with_mask'>431.png
# ./Dataset/<DirEntry 'with_mask'>with_mask314.jpg
# ./Dataset/<DirEntry 'with_mask'>432.png
# ./Dataset/<DirEntry 'with_mask'>0_0_2 copy 17.jpg
# ./Dataset/<DirEntry 'with_mask'>433.png
# ./Dataset/<DirEntry 'with_mask'>0_0_23 copy 4.jpg
# ./Dataset/<DirEntry 'with_mask'>434.png
# ./Dataset/<DirEntry 'with_mask'>with_mask499.jpg
# ./Dataset/<DirEntry 'with_mask'>435.png
# ./Dataset/<DirEntry 'with_mask'>with_mask136.jpeg
# ./Dataset/<DirEntry 'with_mask'>436.png
# ./Dataset/<DirEntry 'with_mask'>1_0_13 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>437.png
# ./Dataset/<DirEntry 'with_mask'>129.jpg
# ./Dataset/<DirEntry 'with_mask'>438.png
# ./Dataset/<DirEntry 'with_mask'>101.jpg
# ./Dataset/<DirEntry 'with_mask'>439.png
# ./Dataset/<DirEntry 'with_mask'>0_0_43.jpg
# ./Dataset/<DirEntry 'with_mask'>440.png
# ./Dataset/<DirEntry 'with_mask'>0_0_14 copy 4.jpg
# ./Dataset/<DirEntry 'with_mask'>441.png
# ./Dataset/<DirEntry 'with_mask'>115.jpg
# ./Dataset/<DirEntry 'with_mask'>442.png
# ./Dataset/<DirEntry 'with_mask'>1_0_5 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>443.png
# ./Dataset/<DirEntry 'with_mask'>with_mask102.jpg
# ./Dataset/<DirEntry 'with_mask'>444.png
# ./Dataset/<DirEntry 'with_mask'>with_mask116.jpg
# ./Dataset/<DirEntry 'with_mask'>445.png
# ./Dataset/<DirEntry 'with_mask'>0_1_3 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>446.png
# ./Dataset/<DirEntry 'with_mask'>0_1_2 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>447.png
# ./Dataset/<DirEntry 'with_mask'>1_0_4a8ee0dfgy1g35gr01fbqj21o0280kjl.jpg
# ./Dataset/<DirEntry 'with_mask'>448.png
# ./Dataset/<DirEntry 'with_mask'>303.jpg
# ./Dataset/<DirEntry 'with_mask'>449.png
# ./Dataset/<DirEntry 'with_mask'>317.jpg
# ./Dataset/<DirEntry 'with_mask'>450.png
# ./Dataset/<DirEntry 'with_mask'>0_0_6e745b4bgy1g78l5uyruxj20f00mi0vo.jpg
# ./Dataset/<DirEntry 'with_mask'>451.png
# ./Dataset/<DirEntry 'with_mask'>0_0_u=458093892,1923361536_fm=26_gp=0.jpg
# ./Dataset/<DirEntry 'with_mask'>452.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 3.jpg
# ./Dataset/<DirEntry 'with_mask'>453.png
# ./Dataset/<DirEntry 'with_mask'>288.jpg
# ./Dataset/<DirEntry 'with_mask'>454.png
# ./Dataset/<DirEntry 'with_mask'>with_mask076.jpg
# ./Dataset/<DirEntry 'with_mask'>455.png
# ./Dataset/<DirEntry 'with_mask'>0_0_≈˙◊¢ 2020-02-24 222124.png
# ./Dataset/<DirEntry 'with_mask'>456.png
# ./Dataset/<DirEntry 'with_mask'>with_mask062.jpg
# ./Dataset/<DirEntry 'with_mask'>457.png
# ./Dataset/<DirEntry 'with_mask'>0_0_35 copy.jpg
# ./Dataset/<DirEntry 'with_mask'>458.png
# ./Dataset/<DirEntry 'with_mask'>0_0_≈˙◊¢ 2020-02-23 132115.png
# ./Dataset/<DirEntry 'with_mask'>459.png
# ./Dataset/<DirEntry 'with_mask'>with_mask089.jpg
# ./Dataset/<DirEntry 'with_mask'>460.png
# ./Dataset/<DirEntry 'with_mask'>with_mask248.png
# ./Dataset/<DirEntry 'with_mask'>461.png
# ./Dataset/<DirEntry 'with_mask'>0_1_17.jpg
# ./Dataset/<DirEntry 'with_mask'>462.png
# ./Dataset/<DirEntry 'with_mask'>0_0_≈˙◊¢ 2020-02-24 205216.png
# ./Dataset/<DirEntry 'with_mask'>463.png
# ./Dataset/<DirEntry 'with_mask'>0_0_6 copy 8.jpg
# ./Dataset/<DirEntry 'with_mask'>464.png
# ./Dataset/<DirEntry 'with_mask'>277.jpg
# ./Dataset/<DirEntry 'with_mask'>465.png
# ./Dataset/<DirEntry 'with_mask'>263.jpg
# ./Dataset/<DirEntry 'with_mask'>466.png
# ./Dataset/<DirEntry 'with_mask'>0_0_006ajtxFly1g5eb2wt4jqj30u00u0myv.jpg
# ./Dataset/<DirEntry 'with_mask'>467.png
# ./Dataset/<DirEntry 'with_mask'>0_0_7 copy 12.jpg
# ./Dataset/<DirEntry 'with_mask'>468.png
# ./Dataset/<DirEntry 'with_mask'>with_mask274.jpg
# ./Dataset/<DirEntry 'with_mask'>469.png
# ./Dataset/<DirEntry 'with_mask'>with_mask512.jpg
# ./Dataset/<DirEntry 'with_mask'>470.png
# ./Dataset/<DirEntry 'with_mask'>with_mask506.jpg
# ./Dataset/<DirEntry 'with_mask'>471.png
# ./Dataset/<DirEntry 'with_mask'>0_0_5 copy 6.jpg
# ./Dataset/<DirEntry 'with_mask'>472.png
# ./Dataset/<DirEntry 'with_mask'>with_mask260.jpg
# ./Dataset/<DirEntry 'with_mask'>473.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 22.jpg
# ./Dataset/<DirEntry 'with_mask'>474.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 36.jpg
# ./Dataset/<DirEntry 'with_mask'>475.png
# ./Dataset/<DirEntry 'with_mask'>1_0_1 copy 15.jpg
# ./Dataset/<DirEntry 'with_mask'>476.png
# ./Dataset/<DirEntry 'with_mask'>1_0_1 copy 14.jpg
# ./Dataset/<DirEntry 'with_mask'>477.png
# ./Dataset/<DirEntry 'with_mask'>0_0_19 copy 6.jpg
# ./Dataset/<DirEntry 'with_mask'>478.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 37.jpg
# ./Dataset/<DirEntry 'with_mask'>479.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 23.jpg
# ./Dataset/<DirEntry 'with_mask'>480.png
# ./Dataset/<DirEntry 'with_mask'>1_0_0 copy 6.jpg
# ./Dataset/<DirEntry 'with_mask'>481.png
# ./Dataset/<DirEntry 'with_mask'>with_mask507.jpg
# ./Dataset/<DirEntry 'with_mask'>482.png
# ./Dataset/<DirEntry 'with_mask'>with_mask261.jpg
# ./Dataset/<DirEntry 'with_mask'>483.png
# ./Dataset/<DirEntry 'with_mask'>0_0_5 copy 7.jpg
# ./Dataset/<DirEntry 'with_mask'>484.png
# ./Dataset/<DirEntry 'with_mask'>with_mask275.jpg
# ./Dataset/<DirEntry 'with_mask'>485.png
# ./Dataset/<DirEntry 'with_mask'>0_0_7 copy 13.jpg
# ./Dataset/<DirEntry 'with_mask'>486.png
# ./Dataset/<DirEntry 'with_mask'>with_mask249.jpg
# ./Dataset/<DirEntry 'with_mask'>487.png
# ./Dataset/<DirEntry 'with_mask'>with_mask225.jpeg
# ./Dataset/<DirEntry 'with_mask'>488.png
# ./Dataset/<DirEntry 'with_mask'>262.jpg
# ./Dataset/<DirEntry 'with_mask'>489.png
# ./Dataset/<DirEntry 'with_mask'>0_0_6 copy 9.jpg
# ./Dataset/<DirEntry 'with_mask'>490.png
# ./Dataset/<DirEntry 'with_mask'>1_0_≈˙◊¢ 2020-02-25 151918.png
# ./Dataset/<DirEntry 'with_mask'>491.png
# ./Dataset/<DirEntry 'with_mask'>276.jpg
# ./Dataset/<DirEntry 'with_mask'>492.png
# ./Dataset/<DirEntry 'with_mask'>0_1_16.jpg
# ./Dataset/<DirEntry 'with_mask'>493.png
# ./Dataset/<DirEntry 'with_mask'>1_1_16.jpg
# ./Dataset/<DirEntry 'with_mask'>494.png
# ./Dataset/<DirEntry 'with_mask'>with_mask088.jpg
# ./Dataset/<DirEntry 'with_mask'>495.png
# ./Dataset/<DirEntry 'with_mask'>with_mask063.jpg
# ./Dataset/<DirEntry 'with_mask'>496.png
# ./Dataset/<DirEntry 'with_mask'>0_0_1 copy.JPEG
# ./Dataset/<DirEntry 'with_mask'>497.png
# ./Dataset/<DirEntry 'with_mask'>with_mask077.jpg
# ./Dataset/<DirEntry 'with_mask'>498.png
# ./Dataset/<DirEntry 'with_mask'>1_0_3 copy 8.jpg
# ./Dataset/<DirEntry 'with_mask'>499.png
# ./Dataset/<DirEntry 'with_mask'>289.jpg
# ./Dataset/<DirEntry 'with_mask'>500.png
# ./Dataset/<DirEntry 'with_mask'>316.jpg
# ./Dataset/<DirEntry 'with_mask'>501.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>502.png
# ./Dataset/<DirEntry 'with_mask'>0_0_006GRRUely1gayhidiee9j31f01w0kjl.jpg
# ./Dataset/<DirEntry 'with_mask'>503.png
# ./Dataset/<DirEntry 'with_mask'>0_0_ab41fce2gy1fyq9t84x99j223u35s1ky.jpg
# ./Dataset/<DirEntry 'with_mask'>504.png
# ./Dataset/<DirEntry 'with_mask'>302.jpg
# ./Dataset/<DirEntry 'with_mask'>505.png
# ./Dataset/<DirEntry 'with_mask'>0_0_c13fabcd4a33401e1cc6ced7cf90f193.jpg
# ./Dataset/<DirEntry 'with_mask'>506.png
# ./Dataset/<DirEntry 'with_mask'>0_0_2.JPEG
# ./Dataset/<DirEntry 'with_mask'>507.png
# ./Dataset/<DirEntry 'with_mask'>with_mask117.jpg
# ./Dataset/<DirEntry 'with_mask'>508.png
# ./Dataset/<DirEntry 'with_mask'>0_0_16 copy 10.jpg
# ./Dataset/<DirEntry 'with_mask'>509.png
# ./Dataset/<DirEntry 'with_mask'>with_mask103.jpg
# ./Dataset/<DirEntry 'with_mask'>510.png
# ./Dataset/<DirEntry 'with_mask'>1_0_21 copy 2.jpg
# ./Dataset/<DirEntry 'with_mask'>511.png
# ./Dataset/<DirEntry 'with_mask'>1_0_5 copy 3.jpg
# ./Dataset/<DirEntry 'with_mask'>512.png
# ./Dataset/<DirEntry 'with_mask'>0_0_14 copy 5.jpg
# ./Dataset/<DirEntry 'with_mask'>513.png
# ./Dataset/<DirEntry 'with_mask'>0_0_42.jpg
# ./Dataset/<DirEntry 'with_mask'>514.png
# ./Dataset/<DirEntry 'with_mask'>114.jpg
# ./Dataset/<DirEntry 'with_mask'>515.png
# ./Dataset/<DirEntry 'with_mask'>100.jpg
# ./Dataset/<DirEntry 'with_mask'>516.png
# ./Dataset/<DirEntry 'with_mask'>0_0_56.jpg
# ./Dataset/<DirEntry 'with_mask'>517.png
# ./Dataset/<DirEntry 'with_mask'>1_0_≈˙◊¢ 2020-02-24 215624.png
# ./Dataset/<DirEntry 'with_mask'>518.png
# ./Dataset/<DirEntry 'with_mask'>128.jpg
# ./Dataset/<DirEntry 'with_mask'>519.png
# ./Dataset/<DirEntry 'with_mask'>0_0_2 copy 16.jpg
# ./Dataset/<DirEntry 'with_mask'>520.png
# ./Dataset/<DirEntry 'with_mask'>with_mask498.jpg
# ./Dataset/<DirEntry 'with_mask'>521.png
# ./Dataset/<DirEntry 'with_mask'>0_0_006ajtxFly1g5eb2x25prj30sk0zowlc.jpg
# ./Dataset/<DirEntry 'with_mask'>522.png
# ./Dataset/<DirEntry 'with_mask'>0_0_23 copy 5.jpg
# ./Dataset/<DirEntry 'with_mask'>523.png
# ./Dataset/<DirEntry 'with_mask'>with_mask473.jpg
# ./Dataset/<DirEntry 'with_mask'>524.png
# ./Dataset/<DirEntry 'with_mask'>with_mask315.jpg
# ./Dataset/<DirEntry 'with_mask'>525.png
# ./Dataset/<DirEntry 'with_mask'>0_0_5 copy 26.jpg
# ./Dataset/<DirEntry 'with_mask'>526.png
# ./Dataset/<DirEntry 'with_mask'>0_0_8 copy 4.jpg
# ./Dataset/<DirEntry 'with_mask'>527.png
# ./Dataset/<DirEntry 'with_mask'>with_mask301.jpg
# ./Dataset/<DirEntry 'with_mask'>528.png
# ./Dataset/<DirEntry 'with_mask'>with_mask467.jpg
# ./Dataset/<DirEntry 'with_mask'>529.png
# ./Dataset/<DirEntry 'with_mask'>0_0_0 copy 2.png
# ./Dataset/<DirEntry 'with_mask'>530.png
# ./Dataset/<DirEntry 'with_mask'>15.jpg
# ./Dataset/<DirEntry 'with_mask'>531.png
# ./Dataset/<DirEntry 'with_mask'>with_mask329.jpg
# ./Dataset/<DirEntry 'with_mask'>532.png
# ./Dataset/<DirEntry 'with_mask'>17.jpg
# ./Dataset/<DirEntry 'with_mask'>533.png
# ./Dataset/<DirEntry 'with_mask'>with_mask459.jpg
# ./Dataset/<DirEntry 'with_mask'>534.png
# ./Dataset/<DirEntry 'with_mask'>0_0_5 copy 18.jpg
# ./Dataset/<DirEntry 'with_mask'>535.png
# ./Dataset/<DirEntry 'with_mask'>0_0_5 copy 30.jpg
# ./Dataset/<DirEntry 'with_mask'>536.png
# ./Dataset/<DirEntry 'with_mask'>with_mask317.jpg
# ./Dataset/<DirEntry 'with_mask'>537.png
# ./Dataset/<DirEntry 'with_mask'>with_mask471.jpg
# ./Dataset/<DirEntry 'with_mask'>538.png
# ./Dataset/<DirEntry 'with_mask'>with_mask465.jpg
# ./Dataset/<DirEntry 'with_mask'>539.png
# ./Dataset/<DirEntry 'with_mask'>with_mask303.jpg
# ...
# ./Dataset/<DirEntry 'without_mask'>1759.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_160.jpg
# ./Dataset/<DirEntry 'without_mask'>1760.png
# ./Dataset/<DirEntry 'without_mask'>1_0_lixirui_0083.jpg
# ./Dataset/<DirEntry 'without_mask'>1761.png
# ./Dataset/<DirEntry 'without_mask'>0_0_fanyichen_0078.jpg
# ./Dataset/<DirEntry 'without_mask'>1762.png
# ./Dataset/<DirEntry 'without_mask'>0_0_liushishi_0063.jpg
# ./Dataset/<DirEntry 'without_mask'>1763.png
# ./Dataset/<DirEntry 'without_mask'>1_0_anhu_0060.jpg
# ./Dataset/<DirEntry 'without_mask'>1764.png
# ./Dataset/<DirEntry 'without_mask'>1_0_shaofeng_0005.jpg
# ./Dataset/<DirEntry 'without_mask'>1765.png
# ./Dataset/<DirEntry 'without_mask'>0_0_yuanshanshan_0001.jpg
# ./Dataset/<DirEntry 'without_mask'>1766.png
# ./Dataset/<DirEntry 'without_mask'>0_0_changshilei_0182.jpg
# ./Dataset/<DirEntry 'without_mask'>1767.png
# ./Dataset/<DirEntry 'without_mask'>1_0_jiayuanyuan_0197.jpg
# ./Dataset/<DirEntry 'without_mask'>1768.png
# ./Dataset/<DirEntry 'without_mask'>0_0_caiguoqing_0093.jpg
# ./Dataset/<DirEntry 'without_mask'>1769.png
# ./Dataset/<DirEntry 'without_mask'>408.jpg
# ./Dataset/<DirEntry 'without_mask'>1770.png
# ./Dataset/<DirEntry 'without_mask'>1_0_anhu_0074.jpg
# ./Dataset/<DirEntry 'without_mask'>1771.png
# ./Dataset/<DirEntry 'without_mask'>0_0_licaihua_0066.jpg
# ./Dataset/<DirEntry 'without_mask'>1772.png
# ./Dataset/<DirEntry 'without_mask'>0_0_sunyizhou_0048.jpg
# ./Dataset/<DirEntry 'without_mask'>1773.png
# ./Dataset/<DirEntry 'without_mask'>420.jpg
# ./Dataset/<DirEntry 'without_mask'>1774.png
# ./Dataset/<DirEntry 'without_mask'>434.jpg
# ./Dataset/<DirEntry 'without_mask'>1775.png
# ./Dataset/<DirEntry 'without_mask'>352.jpg
# ./Dataset/<DirEntry 'without_mask'>1776.png
# ./Dataset/<DirEntry 'without_mask'>0_0_zhaoyazhi_0041.jpg
# ./Dataset/<DirEntry 'without_mask'>1777.png
# ./Dataset/<DirEntry 'without_mask'>1_0_anhu_0048.jpg
# ./Dataset/<DirEntry 'without_mask'>1778.png
# ./Dataset/<DirEntry 'without_mask'>1_0_aidai_0100.jpg
# ./Dataset/<DirEntry 'without_mask'>1779.png
# ./Dataset/<DirEntry 'without_mask'>0_0_wangruoyi_0010.jpg
# ./Dataset/<DirEntry 'without_mask'>1780.png
# ./Dataset/<DirEntry 'without_mask'>0_0_chenyao_0065.jpg
# ./Dataset/<DirEntry 'without_mask'>1781.png
# ./Dataset/<DirEntry 'without_mask'>1_0_aidai_0114.jpg
# ./Dataset/<DirEntry 'without_mask'>1782.png
# ./Dataset/<DirEntry 'without_mask'>1_0_fanshiqi_0086.jpg
# ./Dataset/<DirEntry 'without_mask'>1783.png
# ./Dataset/<DirEntry 'without_mask'>1_0_hanxue_0034.jpg
# ./Dataset/<DirEntry 'without_mask'>1784.png
# ./Dataset/<DirEntry 'without_mask'>385.jpg
# ./Dataset/<DirEntry 'without_mask'>1785.png
# ./Dataset/<DirEntry 'without_mask'>0_0_sunli_0107.jpg
# ./Dataset/<DirEntry 'without_mask'>1786.png
# ./Dataset/<DirEntry 'without_mask'>391.jpg
# ./Dataset/<DirEntry 'without_mask'>1787.png
# ./Dataset/<DirEntry 'without_mask'>1_0_aidai_0128.jpg
# ./Dataset/<DirEntry 'without_mask'>1788.png
# ./Dataset/<DirEntry 'without_mask'>0_0_pengyuyan_0063.jpg
# ./Dataset/<DirEntry 'without_mask'>1789.png
# ./Dataset/<DirEntry 'without_mask'>86.jpg
# ./Dataset/<DirEntry 'without_mask'>1790.png
# ./Dataset/<DirEntry 'without_mask'>0_0_chenxuedong_0070.jpg
# ./Dataset/<DirEntry 'without_mask'>1791.png
# ./Dataset/<DirEntry 'without_mask'>178.jpg
# ./Dataset/<DirEntry 'without_mask'>1792.png
# ./Dataset/<DirEntry 'without_mask'>0_0_caizhuoyan_0048.jpg
# ./Dataset/<DirEntry 'without_mask'>1793.png
# ./Dataset/<DirEntry 'without_mask'>92.jpg
# ./Dataset/<DirEntry 'without_mask'>1794.png
# ./Dataset/<DirEntry 'without_mask'>45.jpg
# ./Dataset/<DirEntry 'without_mask'>1795.png
# ./Dataset/<DirEntry 'without_mask'>1_0_hanxue_0222.jpg
# ./Dataset/<DirEntry 'without_mask'>1796.png
# ./Dataset/<DirEntry 'without_mask'>1_0_jinchen_0070.jpg
# ./Dataset/<DirEntry 'without_mask'>1797.png
# ./Dataset/<DirEntry 'without_mask'>1_0_jinchen_0064.jpg
# ./Dataset/<DirEntry 'without_mask'>1798.png
# ./Dataset/<DirEntry 'without_mask'>3.jpg
# ./Dataset/<DirEntry 'without_mask'>1799.png
# ./Dataset/<DirEntry 'without_mask'>51.jpg
# ./Dataset/<DirEntry 'without_mask'>1800.png
# ./Dataset/<DirEntry 'without_mask'>79.jpg
# ./Dataset/<DirEntry 'without_mask'>1801.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_17.jpg
# ./Dataset/<DirEntry 'without_mask'>1802.png
# ./Dataset/<DirEntry 'without_mask'>0_0_wangdongcheng_0070.jpg
# ./Dataset/<DirEntry 'without_mask'>1803.png
# ./Dataset/<DirEntry 'without_mask'>187.jpg
# ./Dataset/<DirEntry 'without_mask'>1804.png
# ./Dataset/<DirEntry 'without_mask'>193.jpg
# ./Dataset/<DirEntry 'without_mask'>1805.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_216.jpg
# ./Dataset/<DirEntry 'without_mask'>1806.png
# ./Dataset/<DirEntry 'without_mask'>185.jpg
# ./Dataset/<DirEntry 'without_mask'>1807.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_200.jpg
# ./Dataset/<DirEntry 'without_mask'>1808.png
# ./Dataset/<DirEntry 'without_mask'>0_0_jinchen_0120.jpg
# ./Dataset/<DirEntry 'without_mask'>1809.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_214.jpg
# ./Dataset/<DirEntry 'without_mask'>1810.png
# ./Dataset/<DirEntry 'without_mask'>191.jpg
# ./Dataset/<DirEntry 'without_mask'>1811.png
# ./Dataset/<DirEntry 'without_mask'>1_0_jinchen_0072.jpg
# ./Dataset/<DirEntry 'without_mask'>1812.png
# ./Dataset/<DirEntry 'without_mask'>47.jpg
# ./Dataset/<DirEntry 'without_mask'>1813.png
# ./Dataset/<DirEntry 'without_mask'>53.jpg
# ./Dataset/<DirEntry 'without_mask'>1814.png
# ./Dataset/<DirEntry 'without_mask'>1.jpg
# ./Dataset/<DirEntry 'without_mask'>1815.png
# ./Dataset/<DirEntry 'without_mask'>146.jpg
# ./Dataset/<DirEntry 'without_mask'>1816.png
# ./Dataset/<DirEntry 'without_mask'>0_0_jingbairan_0004.jpg
# ./Dataset/<DirEntry 'without_mask'>1817.png
# ./Dataset/<DirEntry 'without_mask'>0_0_chenhaomin_0114.jpg
# ./Dataset/<DirEntry 'without_mask'>1818.png
# ./Dataset/<DirEntry 'without_mask'>152.jpg
# ./Dataset/<DirEntry 'without_mask'>1819.png
# ./Dataset/<DirEntry 'without_mask'>84.jpg
# ./Dataset/<DirEntry 'without_mask'>1820.png
# ./Dataset/<DirEntry 'without_mask'>90.jpg
# ./Dataset/<DirEntry 'without_mask'>1821.png
# ./Dataset/<DirEntry 'without_mask'>1_0_tianliang_0006.jpg
# ./Dataset/<DirEntry 'without_mask'>1822.png
# ./Dataset/<DirEntry 'without_mask'>387.jpg
# ./Dataset/<DirEntry 'without_mask'>1823.png
# ./Dataset/<DirEntry 'without_mask'>0_0_masu_0122.jpg
# ./Dataset/<DirEntry 'without_mask'>1824.png
# ./Dataset/<DirEntry 'without_mask'>393.jpg
# ./Dataset/<DirEntry 'without_mask'>1825.png
# ./Dataset/<DirEntry 'without_mask'>1_0_anhu_0089.jpg
# ./Dataset/<DirEntry 'without_mask'>1826.png
# ./Dataset/<DirEntry 'without_mask'>1_0_hanxue_0036.jpg
# ./Dataset/<DirEntry 'without_mask'>1827.png
# ./Dataset/<DirEntry 'without_mask'>1_0_aidai_0116.jpg
# ./Dataset/<DirEntry 'without_mask'>1828.png
# ./Dataset/<DirEntry 'without_mask'>1_0_jiayuanyuan_0156.jpg
# ./Dataset/<DirEntry 'without_mask'>1829.png
# ./Dataset/<DirEntry 'without_mask'>0_0_chenyao_0073.jpg
# ./Dataset/<DirEntry 'without_mask'>1830.png
# ./Dataset/<DirEntry 'without_mask'>422.jpg
# ./Dataset/<DirEntry 'without_mask'>1831.png
# ./Dataset/<DirEntry 'without_mask'>344.jpg
# ./Dataset/<DirEntry 'without_mask'>1832.png
# ./Dataset/<DirEntry 'without_mask'>350.jpg
# ./Dataset/<DirEntry 'without_mask'>1833.png
# ./Dataset/<DirEntry 'without_mask'>0_0_licaihua_0058.jpg
# ./Dataset/<DirEntry 'without_mask'>1834.png
# ./Dataset/<DirEntry 'without_mask'>1_0_baibaihe_0056.jpg
# ./Dataset/<DirEntry 'without_mask'>1835.png
# ./Dataset/<DirEntry 'without_mask'>436.jpg
# ./Dataset/<DirEntry 'without_mask'>1836.png
# ./Dataset/<DirEntry 'without_mask'>378.jpg
# ./Dataset/<DirEntry 'without_mask'>1837.png
# ./Dataset/<DirEntry 'without_mask'>1_0_fanyichen_0026.jpg
# ./Dataset/<DirEntry 'without_mask'>1838.png
# ./Dataset/<DirEntry 'without_mask'>1_0_fanyichen_0032.jpg
# ./Dataset/<DirEntry 'without_mask'>1839.png
# ./Dataset/<DirEntry 'without_mask'>1_0_anhu_0076.jpg
# ./Dataset/<DirEntry 'without_mask'>1840.png
# ./Dataset/<DirEntry 'without_mask'>1_0_jiayuanyuan_0195.jpg
# ./Dataset/<DirEntry 'without_mask'>1841.png
# ./Dataset/<DirEntry 'without_mask'>0_0_lvyi_0063.jpg
# ./Dataset/<DirEntry 'without_mask'>1842.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_176.jpg
# ./Dataset/<DirEntry 'without_mask'>1843.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_162.jpg
# ./Dataset/<DirEntry 'without_mask'>1844.png
# ./Dataset/<DirEntry 'without_mask'>1_0_lixingliang_0010.jpg
# ./Dataset/<DirEntry 'without_mask'>1845.png
# ./Dataset/<DirEntry 'without_mask'>0_0_ouhao_0017.jpg
# ./Dataset/<DirEntry 'without_mask'>1846.png
# ./Dataset/<DirEntry 'without_mask'>1_0_aidai_0062.jpg
# ./Dataset/<DirEntry 'without_mask'>1847.png
# ./Dataset/<DirEntry 'without_mask'>1_0_aidai_0089.jpg
# ./Dataset/<DirEntry 'without_mask'>1848.png
# ./Dataset/<DirEntry 'without_mask'>230.jpg
# ./Dataset/<DirEntry 'without_mask'>1849.png
# ./Dataset/<DirEntry 'without_mask'>224.jpg
# ./Dataset/<DirEntry 'without_mask'>1850.png
# ./Dataset/<DirEntry 'without_mask'>0_0_masu_0081.jpg
# ./Dataset/<DirEntry 'without_mask'>1851.png
# ./Dataset/<DirEntry 'without_mask'>0_0_liyapeng_0029.jpg
# ./Dataset/<DirEntry 'without_mask'>1852.png
# ./Dataset/<DirEntry 'without_mask'>0_0_aidai_0014.jpg
# ./Dataset/<DirEntry 'without_mask'>1853.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_189.jpg
# ./Dataset/<DirEntry 'without_mask'>1854.png
# ./Dataset/<DirEntry 'without_mask'>0_0_anhu_0211.jpg
# ./Dataset/<DirEntry 'without_mask'>1855.png
# ./Dataset/<DirEntry 'without_mask'>0_0_qiuze_0107.jpg
# ./Dataset/<DirEntry 'without_mask'>1856.png
# ./Dataset/<DirEntry 'without_mask'>1_0_anhu_0116.jpg
# ./Dataset/<DirEntry 'without_mask'>1857.png
# ./Dataset/<DirEntry 'without_mask'>0_0_fanyichen_0091.jpg
# ./Dataset/<DirEntry 'without_mask'>1858.png
# ./Dataset/<DirEntry 'without_mask'>218.jpg
# ./Dataset/<DirEntry 'without_mask'>1859.png
# ./Dataset/<DirEntry 'without_mask'>1_0_anhu_0102.jpg
# ./Dataset/<DirEntry 'without_mask'>1860.png
# ./Dataset/<DirEntry 'without_mask'>0_0_xinzi_0240.jpg
# ./Dataset/<DirEntry 'without_mask'>1861.png
# ./Dataset/<DirEntry 'without_mask'>0_0_anhu_0205.jpg
# ./Dataset/<DirEntry 'without_mask'>1862.png
# ./Dataset/<DirEntry 'without_mask'>0_0_yingzi_0010.jpg
# ./Dataset/<DirEntry 'without_mask'>1863.png
# ./Dataset/<DirEntry 'without_mask'>0_0_lizi_0006.jpg
# ./Dataset/<DirEntry 'without_mask'>1864.png
# ./Dataset/<DirEntry 'without_mask'>1_0_qiqi_0084.jpg
# ./Dataset/<DirEntry 'without_mask'>1865.png
# ./Dataset/<DirEntry 'without_mask'>0_0_zhangrui_0110.jpg
# ./Dataset/<DirEntry 'without_mask'>1866.png
# ./Dataset/<DirEntry 'without_mask'>1_0_sunhonglei_0023.jpg
# ./Dataset/<DirEntry 'without_mask'>1867.png
# ./Dataset/<DirEntry 'without_mask'>0_0_liudehua_0042.jpg
# ./Dataset/<DirEntry 'without_mask'>1868.png
# ./Dataset/<DirEntry 'without_mask'>0_0_zhangzhenyue_0019.jpg
# ./Dataset/<DirEntry 'without_mask'>1869.png
# ./Dataset/<DirEntry 'without_mask'>0_0_raowei_0014.jpg
# ./Dataset/<DirEntry 'without_mask'>1870.png
# ./Dataset/<DirEntry 'without_mask'>0_0_jinchen_0082.jpg
# ./Dataset/<DirEntry 'without_mask'>1871.png
# ./Dataset/<DirEntry 'without_mask'>0_0_xiaozhan_0035.jpg
# ./Dataset/<DirEntry 'without_mask'>1872.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_188.jpg
# ./Dataset/<DirEntry 'without_mask'>1873.png
# ./Dataset/<DirEntry 'without_mask'>1_0_anhu_0117.jpg
# ./Dataset/<DirEntry 'without_mask'>1874.png
# ./Dataset/<DirEntry 'without_mask'>1_0_wanghan_0171.jpg
# ./Dataset/<DirEntry 'without_mask'>1875.png
# ./Dataset/<DirEntry 'without_mask'>225.jpg
# ./Dataset/<DirEntry 'without_mask'>1876.png
# ./Dataset/<DirEntry 'without_mask'>0_0_liyapeng_0028.jpg
# ./Dataset/<DirEntry 'without_mask'>1877.png
# ./Dataset/<DirEntry 'without_mask'>0_0_aidai_0029.jpg
# ./Dataset/<DirEntry 'without_mask'>1878.png
# ./Dataset/<DirEntry 'without_mask'>0_0_caiyilin_0024.jpg
# ./Dataset/<DirEntry 'without_mask'>1879.png
# ./Dataset/<DirEntry 'without_mask'>1_0_lixirui_0057.jpg
# ./Dataset/<DirEntry 'without_mask'>1880.png
# ./Dataset/<DirEntry 'without_mask'>231.jpg
# ./Dataset/<DirEntry 'without_mask'>1881.png
# ./Dataset/<DirEntry 'without_mask'>1_0_aidai_0088.jpg
# ./Dataset/<DirEntry 'without_mask'>1882.png
# ./Dataset/<DirEntry 'without_mask'>1_0_luojin_0038.jpg
# ./Dataset/<DirEntry 'without_mask'>1883.png
# ./Dataset/<DirEntry 'without_mask'>1_0_aidai_0063.jpg
# ./Dataset/<DirEntry 'without_mask'>1884.png
# ./Dataset/<DirEntry 'without_mask'>0_0_fanyichen_0053.jpg
# ./Dataset/<DirEntry 'without_mask'>1885.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_163.jpg
# ./Dataset/<DirEntry 'without_mask'>1886.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_177.jpg
# ./Dataset/<DirEntry 'without_mask'>1887.png
# ./Dataset/<DirEntry 'without_mask'>1_0_anhu_0077.jpg
# ./Dataset/<DirEntry 'without_mask'>1888.png
# ./Dataset/<DirEntry 'without_mask'>1_0_fanyichen_0033.jpg
# ./Dataset/<DirEntry 'without_mask'>1889.png
# ./Dataset/<DirEntry 'without_mask'>0_0_lvyi_0076.jpg
# ./Dataset/<DirEntry 'without_mask'>1890.png
# ./Dataset/<DirEntry 'without_mask'>1_0_fanyichen_0027.jpg
# ./Dataset/<DirEntry 'without_mask'>1891.png
# ./Dataset/<DirEntry 'without_mask'>0_0_lixirui_0071.jpg
# ./Dataset/<DirEntry 'without_mask'>1892.png
# ./Dataset/<DirEntry 'without_mask'>379.jpg
# ./Dataset/<DirEntry 'without_mask'>1893.png
# ./Dataset/<DirEntry 'without_mask'>351.jpg
# ./Dataset/<DirEntry 'without_mask'>1894.png
# ./Dataset/<DirEntry 'without_mask'>437.jpg
# ./Dataset/<DirEntry 'without_mask'>1895.png
# ./Dataset/<DirEntry 'without_mask'>1_0_baibaihe_0057.jpg
# ./Dataset/<DirEntry 'without_mask'>1896.png
# ./Dataset/<DirEntry 'without_mask'>0_0_pubajia_0049.jpg
# ./Dataset/<DirEntry 'without_mask'>1897.png
# ./Dataset/<DirEntry 'without_mask'>423.jpg
# ./Dataset/<DirEntry 'without_mask'>1898.png
# ./Dataset/<DirEntry 'without_mask'>345.jpg
# ./Dataset/<DirEntry 'without_mask'>1899.png
# ./Dataset/<DirEntry 'without_mask'>1_0_aidai_0117.jpg
# ./Dataset/<DirEntry 'without_mask'>1900.png
# ./Dataset/<DirEntry 'without_mask'>1_0_chenyao_0108.jpg
# ./Dataset/<DirEntry 'without_mask'>1901.png
# ./Dataset/<DirEntry 'without_mask'>1_0_anhu_0088.jpg
# ./Dataset/<DirEntry 'without_mask'>1902.png
# ./Dataset/<DirEntry 'without_mask'>392.jpg
# ./Dataset/<DirEntry 'without_mask'>1903.png
# ./Dataset/<DirEntry 'without_mask'>1_0_tianliang_0013.jpg
# ./Dataset/<DirEntry 'without_mask'>1904.png
# ./Dataset/<DirEntry 'without_mask'>1_0_tianliang_0007.jpg
# ./Dataset/<DirEntry 'without_mask'>1905.png
# ./Dataset/<DirEntry 'without_mask'>0_0_sunli_0104.jpg
# ./Dataset/<DirEntry 'without_mask'>1906.png
# ./Dataset/<DirEntry 'without_mask'>386.jpg
# ./Dataset/<DirEntry 'without_mask'>1907.png
# ./Dataset/<DirEntry 'without_mask'>91.jpg
# ./Dataset/<DirEntry 'without_mask'>1908.png
# ./Dataset/<DirEntry 'without_mask'>1_0_benxi_0108.jpg
# ./Dataset/<DirEntry 'without_mask'>1909.png
# ./Dataset/<DirEntry 'without_mask'>0_0_songzuer_0079.jpg
# ./Dataset/<DirEntry 'without_mask'>1910.png
# ./Dataset/<DirEntry 'without_mask'>153.jpg
# ./Dataset/<DirEntry 'without_mask'>1911.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_229.jpg
# ./Dataset/<DirEntry 'without_mask'>1912.png
# ./Dataset/<DirEntry 'without_mask'>52.jpg
# ./Dataset/<DirEntry 'without_mask'>1913.png
# ./Dataset/<DirEntry 'without_mask'>0_0_songzuer_0086.jpg
# ./Dataset/<DirEntry 'without_mask'>1914.png
# ./Dataset/<DirEntry 'without_mask'>0.jpg
# ./Dataset/<DirEntry 'without_mask'>1915.png
# ./Dataset/<DirEntry 'without_mask'>0_0_jiayuanyuan_0130.jpg
# ./Dataset/<DirEntry 'without_mask'>1916.png
# ./Dataset/<DirEntry 'without_mask'>1_0_hanxue_0221.jpg
# ./Dataset/<DirEntry 'without_mask'>1917.png
# ./Dataset/<DirEntry 'without_mask'>46.jpg
# ./Dataset/<DirEntry 'without_mask'>1918.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_215.jpg
# ./Dataset/<DirEntry 'without_mask'>1919.png
# ./Dataset/<DirEntry 'without_mask'>184.jpg
# ./Dataset/<DirEntry 'without_mask'>1920.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_14.jpg
# ./Dataset/<DirEntry 'without_mask'>1921.png
# ./Dataset/<DirEntry 'without_mask'>0_0_cengyongti_0091.jpg
# ./Dataset/<DirEntry 'without_mask'>1922.png
# ./Dataset/<DirEntry 'without_mask'>augmented_image_201.jpg
# ./Dataset/<DirEntry 'without_mask'>1923.png
# ./Dataset/<DirEntry 'without_mask'>0_0_chenhuilin_0018.jpg
# ./Dataset/<DirEntry 'without_mask'>1924.png

# %%
def cropImage(imgPath):
    image = cv2.imread(imgPath)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        colorImg = image[y:y+h, x:x+w]
        if (len(faces)>0):
            return (colorImg)

# %%
ogpic = cv2.imread('./rawDataset/widow/widow-12.png')
plt.imshow(ogpic)

# %%
crop = cropImage('./rawDataset/widow/widow-12.png')
plt.imshow(crop)

# %%
path_to_data = "./rawDataset/"
path_to_crop = "./Dataset/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)
        
img_dirs
# Out:
# ['./rawDataset/thor',
#  './rawDataset/hulk',
#  './rawDataset/cap',
#  './rawDataset/widow',
#  './rawDataset/iron',
#  './rawDataset/hawk']

# %%
os.mkdir(path_to_crop)

# %%
cropped_image_dirs = []
char_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    char_name = img_dir.split('/')[-1]
    print(char_name)
    
    char_file_names_dict[char_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = cropImage(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_crop + char_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = char_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            char_file_names_dict[char_name].append(cropped_file_path)
            count += 1
# Out:
# thor
# Generating cropped images in folder:  ./Dataset/thor
# hulk
# Generating cropped images in folder:  ./Dataset/hulk
# cap
# Generating cropped images in folder:  ./Dataset/cap
# widow
# Generating cropped images in folder:  ./Dataset/widow
# iron
# Generating cropped images in folder:  ./Dataset/iron
# hawk
# Generating cropped images in folder:  ./Dataset/hawk

# %%
final_img_dirs =[]
for entry in os.scandir(path_to_crop):
    if entry.is_dir():
        final_img_dirs.append(entry.path)
final_img_dirs
# Out:
# ['./Dataset/thor',
#  './Dataset/hulk',
#  './Dataset/cap',
#  './Dataset/widow',
#  './Dataset/iron',
#  './Dataset/hawk']

# %%
final_count = 0
for final_img_dir in final_img_dirs:
    
    for entry in os.scandir(final_img_dir):
        final_count += 1
    print(final_count, final_img_dir.split('/')[-1])
    final_count = 0
# Out:
# 91 thor
# 107 hulk
# 92 cap
# 103 widow
# 100 iron
# 98 hawk

# %%
# cv2.imshow("Test", img)

# cv2.waitKey(0) & 0xFF #Delay. No. of Milliseconds for which we want to show our image window
# cv2.destroyAllWindows()
# cv2.waitKey(1)
